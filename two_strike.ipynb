# %%
import pybaseball as pb
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.ticker

# %%
batting_25 = pb.batting_stats(2025)

# %%
batting_25.plot(kind='scatter', x='O-Swing%', y='O-Contact%')
# Out:
# <Axes: xlabel='O-Swing%', ylabel='O-Contact%'>

# %%
batting_25.plot(kind='scatter', y='K%', x='O-Contact%')
# Out:
# <Axes: xlabel='O-Contact%', ylabel='K%'>
